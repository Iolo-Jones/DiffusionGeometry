# %%
import os

def getListOfFiles(dirName):
    # create a list of file and sub directories 
    # names in the given directory 
    listOfFile = os.listdir(dirName)
    allFiles = list()
    # Iterate over all the entries
    for entry in listOfFile:
        # Create full path
        fullPath = os.path.join(dirName, entry)
        # If entry is a directory then get the list of files in this directory 
        if os.path.isdir(fullPath):
            allFiles = allFiles + getListOfFiles(fullPath)
        else:
            allFiles.append(fullPath)
                
    return allFiles

# %%
id_dict = {'33754-07': 'T_A',
          '16089-08': 'T_B',
          '19065-08': 'T_C',
          '3778-08': 'T_D',
          '22680': 'T_E',
          27066: 'T_F',
          38648: 'T_G',
          5388: 'T_H',
          13951: 'T_I',
          7170: 'T_J',
          8944: 'T_K',
          15621: 'T_L',
          20855: 'T_M',
          21752: 'T_N',
          24131: 'T_O',
          6327: 'T_P'}

path = '/home/ollie/Documents/RIVET/JB-HAH-OV-Collaboration/CD8vCD68vFoxP3_Comparison/NoNormalisation/NoStandardisationTableFigures/AvgLandscapes/' 
files = getListOfFiles(path)
files
# Out:
# ['/home/ollie/Documents/RIVET/JB-HAH-OV-Collaboration/CD8vCD68vFoxP3_Comparison/NoNormalisation/NoStandardisationTableFigures/AvgLandscapes/33754CD8Average.pdf',
#  '/home/ollie/Documents/RIVET/JB-HAH-OV-Collaboration/CD8vCD68vFoxP3_Comparison/NoNormalisation/NoStandardisationTableFigures/AvgLandscapes/5388CD8Average.pdf',
#  '/home/ollie/Documents/RIVET/JB-HAH-OV-Collaboration/CD8vCD68vFoxP3_Comparison/NoNormalisation/NoStandardisationTableFigures/AvgLandscapes/15621CD68Average.pdf',
#  '/home/ollie/Documents/RIVET/JB-HAH-OV-Collaboration/CD8vCD68vFoxP3_Comparison/NoNormalisation/NoStandardisationTableFigures/AvgLandscapes/3778CD8Average.pdf',
#  '/home/ollie/Documents/RIVET/JB-HAH-OV-Collaboration/CD8vCD68vFoxP3_Comparison/NoNormalisation/NoStandardisationTableFigures/AvgLandscapes/13951CD8Average.pdf',
#  '/home/ollie/Documents/RIVET/JB-HAH-OV-Collaboration/CD8vCD68vFoxP3_Comparison/NoNormalisation/NoStandardisationTableFigures/AvgLandscapes/22680CD68Average.pdf',
# ...

# %%
for key in id_dict:
    print(key)
    files_to_rename = [fn for fn in files if str(key) in fn]
    for fn in files_to_rename:
        print(fn, fn.replace(str(key),id_dict[key]))
        os.rename(fn, fn.replace(str(key),id_dict[key]))
# Out:
# 33754
# /home/ollie/Documents/RIVET/JB-HAH-OV-Collaboration/CD8vCD68vFoxP3_Comparison/NoNormalisation/NoStandardisationTableFigures/AvgLandscapes/33754CD8Average.pdf /home/ollie/Documents/RIVET/JB-HAH-OV-Collaboration/CD8vCD68vFoxP3_Comparison/NoNormalisation/NoStandardisationTableFigures/AvgLandscapes/T_ACD8Average.pdf
# /home/ollie/Documents/RIVET/JB-HAH-OV-Collaboration/CD8vCD68vFoxP3_Comparison/NoNormalisation/NoStandardisationTableFigures/AvgLandscapes/33754CD68Average.pdf /home/ollie/Documents/RIVET/JB-HAH-OV-Collaboration/CD8vCD68vFoxP3_Comparison/NoNormalisation/NoStandardisationTableFigures/AvgLandscapes/T_ACD68Average.pdf
# /home/ollie/Documents/RIVET/JB-HAH-OV-Collaboration/CD8vCD68vFoxP3_Comparison/NoNormalisation/NoStandardisationTableFigures/AvgLandscapes/33754FoxP3Average.pdf /home/ollie/Documents/RIVET/JB-HAH-OV-Collaboration/CD8vCD68vFoxP3_Comparison/NoNormalisation/NoStandardisationTableFigures/AvgLandscapes/T_AFoxP3Average.pdf
# 16089
# ...

# %%
os.rename('guru99.txt','career.guru99.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-dd4a31cb50dd> in <module>
# ----> 1 os.rename('guru99.txt','career.guru99.txt')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'guru99.txt' -> 'career.guru99.txt'

# %%
# Replace [19065] with 19065
# files_to_rename = [fn for fn in files if '[19065]' in fn]
# for fn in files_to_rename:
#     print(fn, fn.replace('[19065]','19065'))
#     os.rename(path+fn,path+ fn.replace('[19065]','19065'))
# Out:
# Tumour[19065]CD810NNCodensitySample22RipsMax1.txtH1x30y30.rivet Tumour19065CD810NNCodensitySample22RipsMax1.txtH1x30y30.rivet
# Tumour[19065]CD810NNCodensitySample9RipsMax1.txtH1x30y30.rivet Tumour19065CD810NNCodensitySample9RipsMax1.txtH1x30y30.rivet
# Tumour[19065]FoxP310NNCodensitySample11RipsMax1.txtH1x30y30.rivet Tumour19065FoxP310NNCodensitySample11RipsMax1.txtH1x30y30.rivet
# Tumour[19065]CD6810NNCodensitySample5RipsMax1.txtH1x30y30.rivet Tumour19065CD6810NNCodensitySample5RipsMax1.txtH1x30y30.rivet
# Tumour[19065]FoxP310NNCodensitySample44RipsMax1.txtH1x30y30.rivet Tumour19065FoxP310NNCodensitySample44RipsMax1.txtH1x30y30.rivet
# Tumour[19065]CD6810NNCodensitySample41RipsMax1.txtH1x30y30.rivet Tumour19065CD6810NNCodensitySample41RipsMax1.txtH1x30y30.rivet
# Tumour[19065]FoxP310NNCodensitySample15RipsMax1.txtH1x30y30.rivet Tumour19065FoxP310NNCodensitySample15RipsMax1.txtH1x30y30.rivet
# ...
